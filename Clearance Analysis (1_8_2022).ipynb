# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
district = 3

shot_data_raw = pd.read_csv('Shotspotter_through_2021.csv')
shot_data_raw=shot_data_raw[shot_data_raw["DISTRICT"]==district]
for i in shot_data_raw.index:
    x=shot_data_raw.loc[i,"DATE"]
    x1=x.split(' ')
    x2=x1[0].split('/')
    shot_data_raw.loc[i,"time"]=x1[1]
    shot_data_raw.loc[i,'MONTH'] =int(x2[0])
    shot_data_raw.loc[i,"day"]=x2[1]
    shot_data_raw.loc[i,"YEAR"]=int(x2[2])
shot_data_raw=shot_data_raw.reset_index(drop=True)
shot_data_raw=shot_data_raw[["DATE","YEAR","MONTH","LATITUDE","LONGITUDE","LOCATION"]]

# %%
# if arrest = 0, it is not factored in.
# if arrest = 1, it is factored in.
crime_data_raw = pd.read_csv('Crimes_through_2021.csv')
shooting_data_raw= pd.read_csv('Shootings_through_2021.csv')

# %%
def clean(df, district, arrest):
    if arrest == 1:
        for i in df.index:
            x=df.loc[i,"Date"]
            x1=x.split(' ')
            x2=x1[0].split('/')
            df.loc[i,'MONTH'] =int(x2[0])
            df.loc[i,"YEAR"]=int(x2[2])
        df.columns
        df= df[df['District'] == int(district)]
        df= df[['Case Number', 'Date','Arrest','Year','MONTH','District','Latitude', 'Longitude','Location']]
        df['linked'] = 0
        # df= df[df['Arrest'] == True]
        df.columns=["CASE ID", "DATE","ARREST","YEAR","MONTH","DISTRICT","LATITUDE","LONGITUDE","LOCATION","spotted"]
    elif arrest == 0:
        for i in df.index:
            x=df.loc[i,"DATE"]
            x1=x.split(' ')
            x2=x1[0].split('/')
            df.loc[i,'MONTH'] =int(x2[0])
            df.loc[i,"YEAR"]=int(x2[2])
            df.columns
        df= df[df['DISTRICT'] == int(district)]
        df = df[["CASE_NUMBER","DATE","YEAR","MONTH","DISTRICT","GUNSHOT_INJURY_I","LATITUDE","LONGITUDE"]]
        df = df[df["GUNSHOT_INJURY_I"]=='YES']
        df['linked'] = 0
        df['ARREST'] = -1
    else:
        for i in df.index:
            x=df.loc[i,"Date"]
            x1=x.split(' ')
            x2=x1[0].split('/')
            df.loc[i,'MONTH'] =int(x2[0])
            df.loc[i,"YEAR"]=int(x2[2])
        df.columns
        df= df[df['District'] == int(district)]
        df= df[['Date','Year','MONTH','District','Latitude', 'Longitude','Location']]
        df['linked'] = 0
        df.columns=["DATE","YEAR","MONTH","DISTRICT","LATITUDE","LONGITUDE","LATITUDE","spotted"]
    df= df.reset_index(drop=True)
    return df

# %%
crime_data_raw = clean(crime_data_raw, 3, 1)
crime_data_raw.head()
# Out:
#     CASE ID                    DATE  ARREST  YEAR  MONTH  DISTRICT   LATITUDE  \
# 0  JB101142  01/01/2018 10:54:00 PM    True  2018    1.0         3  41.784966
# 1  JB101152  01/02/2018 12:50:00 AM    True  2018    1.0         3  41.782843
# 2  JB101767  01/02/2018 02:55:00 PM    True  2018    1.0         3  41.777465
# 3  JB102191  01/02/2018 07:35:00 PM    True  2018    1.0         3  41.774108
# 4  JB103390  01/03/2018 07:15:00 PM    True  2018    1.0         3  41.767449
#
#    LONGITUDE                       LOCATION  spotted
# 0 -87.615743  (41.784966318, -87.615743293)        0
# 1 -87.623775  (41.782842728, -87.623774676)        0
# 2 -87.617264  (41.777464689, -87.617264087)        0
# 3 -87.592930  (41.774107849, -87.592929644)        0
# 4 -87.585957  (41.767448959, -87.585957168)        0

# %%
shooting_data_raw = clean(shooting_data_raw,3,0)
shooting_data_raw.head()
# Out:
#   CASE_NUMBER                    DATE    YEAR  MONTH  DISTRICT  \
# 0     A034100  01/23/1996 04:35:00 PM  1996.0      1       3.0
# 1     A084677  02/04/1996 07:00:00 AM  1996.0      2       3.0
# 2     A094921  02/09/1996 11:13:00 PM  1996.0      2       3.0
# 3     A122257  02/25/1996 12:15:00 AM  1996.0      2       3.0
# 4     A123844  02/25/1996 10:28:00 PM  1996.0      2       3.0
#
#   GUNSHOT_INJURY_I   LATITUDE  LONGITUDE  linked  ARREST
# 0              YES  41.784330 -87.613289       0      -1
# 1              YES  41.765432 -87.614685       0      -1
# 2              YES  41.770943 -87.583371       0      -1
# 3              YES  41.758292 -87.617645       0      -1
# 4              YES  41.767997 -87.568081       0      -1

# %%
# !!pip install geopy
from geopy import distance
import datetime
import re
pt1 = [shooting_data_raw.loc[3,"LATITUDE"],shooting_data_raw.loc[3,"LONGITUDE"]]
pt2 = [shot_data_raw.loc[1,"LATITUDE"],shot_data_raw.loc[1,"LONGITUDE"]]
print("Distance between events is ", distance.distance(pt1, pt2).km, ' km')
strdate1 = shooting_data_raw.loc[3,"DATE"]
strdate2 = shot_data_raw.loc[1,"DATE"]
date1 = datetime.datetime.strptime(strdate1, "%m/%d/%Y %H:%M:%S %p")
date2 = datetime.datetime.strptime(strdate2, "%m/%d/%Y %H:%M:%S %p")
dt = date1-date2
print(date1)
print(date2)
print("Time between events is ", int(dt.total_seconds()/60))
# Out:
# Distance between events is  2.1105175960629547  km
# 1996-02-25 12:15:00
# 2018-02-06 04:12:47
# Time between events is  -11543997

# %%
def linked(df, P, T, delta, tau):
    for k in range(P.shape[0]):
        for q in range(P.shape[1]):
            if P[k][q] < delta and T[k][q] < tau and T[k][q] >= 0:
                df.loc[k, 'linked'] += 1

# %%
def LD(hom_data,shot_data,year,month,delta,tau,crime_data):
    #install libraries
    from geopy import distance
    import datetime
    #get the threshold values
    delta = delta
    tau = tau
    hom_data = hom_data[hom_data["YEAR"]==year]
    shot_data = shot_data[shot_data["YEAR"]==year]
    hom_data = hom_data[hom_data["MONTH"]==month]
    shot_data = shot_data[shot_data["MONTH"]==month]
    shot_data = shot_data.reset_index(drop = True)
    hom_data = hom_data.reset_index(drop=True)
    #define the function to determine linkage of shotspotter and shooting incidents based on the threshold values
    #Create the P and T matrices
    P = np.zeros((hom_data.shape[0], shot_data.shape[0]))
    T = np.zeros((hom_data.shape[0], shot_data.shape[0]))
    for i in hom_data.index:
        for j in shot_data.index:
            pt1 = [hom_data.loc[i,"LATITUDE"],hom_data.loc[i,"LONGITUDE"]]
            pt2 = [shot_data.loc[j,"LATITUDE"],shot_data.loc[j,"LONGITUDE"]]
            P[i][j] = distance.distance(pt1, pt2).km
            strdate1 = hom_data.loc[i,"DATE"]
            strdate2 = shot_data.loc[j,"DATE"]
            date1 = datetime.datetime.strptime(strdate1, "%m/%d/%Y %H:%M:%S %p")
            date2 = datetime.datetime.strptime(strdate2, "%m/%d/%Y %H:%M:%S %p")
            dt = date1-date2
            T[i][j] = int(dt.total_seconds() / 60)
    #Apply the function linked to the P and T matrices
    linked(hom_data, P,T,delta,tau)
    #Matching case number from hom_data to crime data
    for i in hom_data.index:
        for j in crime_data.index:
            if hom_data.loc[i,"CASE_NUMBER"]== crime_data.loc[j,"CASE ID"]:
                if crime_data.loc[j,'ARREST'] == True:
                    hom_data.loc[i,"ARREST"] = 1
                elif crime_data.loc[j,'ARREST'] == False:
                    hom_data.loc[i, "ARREST"] = 0
    #return the linking distribution
    return hom_data

# %%
## link events with spotted
delta=.3
tau=30
hom_data = pd.DataFrame()
for yr in np.arange(0, 4, 1):
    for mo in np.arange(0,12,1):
        hom_data = pd.concat([hom_data, LD(shooting_data_raw,shot_data_raw,2018+yr,mo+1,delta,tau,crime_data_raw)])
hom_data.head(10)
# Out:
#   CASE_NUMBER                    DATE    YEAR  MONTH  DISTRICT  \
# 0    JB105277  01/05/2018 12:10:00 PM  2018.0      1       3.0
# 1    JB120039  01/18/2018 02:51:00 AM  2018.0      1       3.0
# 2    JB120039  01/18/2018 02:51:00 AM  2018.0      1       3.0
# 3    JB106414  01/06/2018 11:12:00 AM  2018.0      1       3.0
# 4    JB106581  01/06/2018 01:00:00 PM  2018.0      1       3.0
# 5    JB101767  01/02/2018 02:55:00 PM  2018.0      1       3.0
# 0    JB138202  02/02/2018 12:04:00 AM  2018.0      2       3.0
# 1    JB150050  02/13/2018 12:57:00 AM  2018.0      2       3.0
# 2    JB138202  02/02/2018 12:04:00 AM  2018.0      2       3.0
# 0    JB206060  03/31/2018 03:30:00 AM  2018.0      3       3.0
#
#   GUNSHOT_INJURY_I   LATITUDE  LONGITUDE  linked  ARREST
# 0              YES  41.782812 -87.589285       0      -1
# 1              YES  41.774193 -87.607159       0      -1
# 2              YES  41.774193 -87.607159       0      -1
# 3              YES  41.769277 -87.568141       0       1
# 4              YES  41.772433 -87.609251       0       1
# 5              YES  41.777282 -87.617845       0       1
# 0              YES  41.761908 -87.622925       0       0
# 1              YES  41.770020 -87.615719       1       0
# 2              YES  41.761908 -87.622925       0       0
# 0              YES  41.775380 -87.603379       2      -1

# %%
hom_data["LINKED"] = 0
hom_data["CLEARED"] = 0
hom_data= hom_data.reset_index(drop=True)
for i in hom_data.index:
    if hom_data.loc[i, 'linked'] > 0:
        hom_data.loc[i, 'LINKED'] = 1
    if hom_data.loc[i, 'ARREST'] == 1:
        hom_data.loc[i, 'CLEARED'] = 1
    if hom_data.loc[i, 'ARREST'] == -1:
        hom_data.loc[i, 'CLEARED'] = -1
hom_data = hom_data.drop(columns=['DATE', 'LATITUDE', 'LONGITUDE','GUNSHOT_INJURY_I'])
hom_data = hom_data.rename(columns = {'spotted':'SPOTTED'})

# %%
hom_data.head(100)
# Out:
#    CASE_NUMBER    YEAR  MONTH  DISTRICT  linked  ARREST  LINKED  CLEARED
# 0     JB105277  2018.0      1       3.0       0      -1       0       -1
# 1     JB120039  2018.0      1       3.0       0      -1       0       -1
# 2     JB120039  2018.0      1       3.0       0      -1       0       -1
# 3     JB106414  2018.0      1       3.0       0       1       0        1
# 4     JB106581  2018.0      1       3.0       0       1       0        1
# 5     JB101767  2018.0      1       3.0       0       1       0        1
# 6     JB138202  2018.0      2       3.0       0       0       0        0
# 7     JB150050  2018.0      2       3.0       1       0       1        0
# 8     JB138202  2018.0      2       3.0       0       0       0        0
# 9     JB206060  2018.0      3       3.0       2      -1       1       -1
# 10    JB172223  2018.0      3       3.0       1       0       1        0
# 11    JB172223  2018.0      3       3.0       1       0       1        0
# 12    JB174987  2018.0      3       3.0       0       0       0        0
# 13    JB178862  2018.0      3       3.0       0       0       0        0
# 14    JB180384  2018.0      3       3.0       0       0       0        0
# 15    JB194695  2018.0      3       3.0       0       0       0        0
# 16    JB197736  2018.0      3       3.0       0       0       0        0
# 17    JB197736  2018.0      3       3.0       0       0       0        0
# 18    JB201781  2018.0      3       3.0       1       0       1        0
# 19    JB237945  2018.0      4       3.0       0      -1       0       -1
# 20    JB232062  2018.0      4       3.0       1      -1       1       -1
# 21    JB207922  2018.0      4       3.0       0       0       0        0
# 22    JB210393  2018.0      4       3.0       0       0       0        0
# 23    JB223285  2018.0      4       3.0       0       0       0        0
# 24    JB224198  2018.0      4       3.0       0       0       0        0
# 25    JB224198  2018.0      4       3.0       0       0       0        0
# 26    JB232062  2018.0      4       3.0       1      -1       1       -1
# 27    JB232062  2018.0      4       3.0       1      -1       1       -1
# 28    JB232508  2018.0      4       3.0       0       0       0        0
# 29    JB218179  2018.0      4       3.0       0       0       0        0
# ..         ...     ...    ...       ...     ...     ...     ...      ...
# 70    JB310816  2018.0      6       3.0       1       0       1        0
# 71    JB312361  2018.0      6       3.0       0       0       0        0
# 72    JB315550  2018.0      6       3.0       1       0       1        0
# 73    JB319952  2018.0      6       3.0       3       0       1        0
# 74    JB320448  2018.0      6       3.0       2       0       1        0
# 75    JB320448  2018.0      6       3.0       2       0       1        0
# 76    JB320448  2018.0      6       3.0       2       0       1        0
# 77    JB321352  2018.0      6       3.0       2       0       1        0
# 78    JB325454  2018.0      6       3.0       0       0       0        0
# 79    JB326585  2018.0      6       3.0       0       1       0        1
# 80    JB329701  2018.0      6       3.0       0       0       0        0
# 81    JB326935  2018.0      6       3.0       1       0       1        0
# 82    JB322395  2018.0      6       3.0       1       0       1        0
# 83    JB322509  2018.0      6       3.0       1       0       1        0
# 84    JB326935  2018.0      6       3.0       1       0       1        0
# 85    JB354385  2018.0      7       3.0       1       0       1        0
# 86    JB354385  2018.0      7       3.0       1       0       1        0
# 87    JB348808  2018.0      7       3.0       1      -1       1       -1
# 88    JB345145  2018.0      7       3.0       0       0       0        0
# 89    JB341451  2018.0      7       3.0       0       0       0        0
# 90    JB347368  2018.0      7       3.0       1       0       1        0
# 91    JB350079  2018.0      7       3.0       1       0       1        0
# 92    JB352406  2018.0      7       3.0       1       0       1        0
# 93    JB352406  2018.0      7       3.0       1       0       1        0
# 94    JB357710  2018.0      7       3.0       0       0       0        0
# 95    JB362510  2018.0      7       3.0       0       0       0        0
# 96    JB362550  2018.0      7       3.0       2       0       1        0
# 97    JB362674  2018.0      7       3.0       1       0       1        0
# 98    JB363754  2018.0      7       3.0       0       0       0        0
# 99    JB363754  2018.0      7       3.0       0       0       0        0
#
# [100 rows x 8 columns]

# %%
delta=.3
tau=30

def linkageRatio(delta, tau, homData):
    total = [0 for x in range(4)]
    linked = [0 for x in range(4)]
    ratio = [0 for x in range(4)]
    for yr in np.arange(0, 4, 1):
        df = homData[homData['YEAR'] == 2018 + yr]
        total[yr] = len(df)
        df = df[df['LINKED'] == 1]
        linked[yr] = len(df)
        ratio[yr] = linked[yr]/total[yr]
    return [ratio, linked, total]

# %%
totalLinkage = linkageRatio(delta, tau, hom_data)
hom_data_cleared = hom_data[hom_data['CLEARED'] == 1]
hom_data_not_cleared = hom_data[hom_data['CLEARED'] == 0]
clearedLinkage = linkageRatio(delta, tau, hom_data_cleared)
nonclearedLinkage = linkageRatio(delta, tau, hom_data_not_cleared)
print(nonclearedLinkage)
print(clearedLinkage)
# Out:
# [[0.5533333333333333, 0.5811965811965812, 0.5824742268041238, 0.5223214285714286], [83, 68, 113, 117], [150, 117, 194, 224]]
# [[0.5, 0.75, 0.42857142857142855, 0.5714285714285714], [5, 3, 3, 4], [10, 4, 7, 7]]

# %%
totalLinkage[0][1]
# Out:
# 0.5743243243243243

# %%
clearedLinkage
# Out:
# [[0.5, 0.75, 0.42857142857142855, 0.5714285714285714],
#  [5, 3, 3, 4],
#  [10, 4, 7, 7]]

# %%
fig, ax = plt.subplots(figsize = [10, 5])
#matrix n x m = 4 x 3
x = np.arange(1)
for i in np.arange(4):
    plt.bar((x + i) - .15, nonclearedLinkage[2][i], width = 0.3, color = 'grey',alpha=.1)
    plt.bar((x + i) - .15, nonclearedLinkage[1][i], width = 0.3, color = 'grey', alpha=.4)
    plt.bar((x + i) + .15, clearedLinkage[2][i], width = 0.3, color = 'k',alpha=.6)
    plt.bar((x + i) + .15, clearedLinkage[1][i], width = 0.3, color = 'k', alpha=1)
years = ['2018', '2019', '2020', '2021']

plt.xticks(np.arange(len(years)), years, size = 12)

ax.set_ylabel('Number of Events', color = 'k')
ax.set_xlabel("Year", color = 'k', size = 15)
for j in np.arange(0,4,1):
    plt.text(j-.22,nonclearedLinkage[2][j]+.1,str(nonclearedLinkage[2][j]),size = 12)
for j in np.arange(0,4,1):
    plt.text(j-.22,nonclearedLinkage[1][j]+.1,str(nonclearedLinkage[1][j]),size = 12)
for j in np.arange(0,4,1):
    plt.text(j+.18,clearedLinkage[2][j]+.1,str(clearedLinkage[2][j]),size = 12)
for j in np.arange(0,4,1):
    plt.text(j+.08,clearedLinkage[1][j]+.1,str(clearedLinkage[1][j]),size = 12)
import matplotlib.patches as mpatches
grey1 = mpatches.Patch(color='grey', label='Total Noncleared Shootings',alpha=.1)
grey2 = mpatches.Patch(label='Noncleared Linked Shootings', color='grey', alpha=.4)
black1 = mpatches.Patch(color='k', label='Total Cleared Shootings',alpha=.6)
black2 = mpatches.Patch(color='k', label='Cleared Linked Shootings',alpha=1)
plt.legend(handles=[grey1, grey2, black1, black2])

plt.title("Clearance of Shootings and their Linkage with Shotspotter Alerts")
plt.savefig("LinkageClearance.png")
